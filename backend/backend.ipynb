# %%
# Install dependencies (run once)
# !pip install fastapi sqlalchemy uvicorn nest_asyncio pydantic streamlit requests pandas

# ------------------------------
# Imports
import nest_asyncio
nest_asyncio.apply()

from fastapi import FastAPI
from pydantic import BaseModel
from datetime import datetime
from sqlalchemy import create_engine, Column, Integer, String, Float, DateTime, JSON
from sqlalchemy.orm import declarative_base, sessionmaker
import uvicorn
import threading

# ------------------------------
# Initialize FastAPI
app = FastAPI(title="Real-Time Traffic Prediction API")

# Database setup
DATABASE_URL = "sqlite:///./traffic.db"
engine = create_engine(DATABASE_URL, connect_args={"check_same_thread": False})
SessionLocal = sessionmaker(bind=engine, autocommit=False, autoflush=False)
Base = declarative_base()

# ------------------------------
# Database Model
class Prediction(Base):
    __tablename__ = "predictions"
    id = Column(Integer, primary_key=True, index=True)
    segment_id = Column(String, index=True)
    timestamp = Column(DateTime, default=datetime.utcnow)
    horizon_min = Column(Integer)
    predicted_speed = Column(Float)
    metadata_json = Column(JSON)

Base.metadata.create_all(bind=engine)

# ------------------------------
# Request Model
class TrafficData(BaseModel):
    segment_id: str
    horizon_min: int
    predicted_speed: float
    model: str

# ------------------------------
# API Endpoints
@app.get("/health")
def health_check():
    return {"status": "API is running!"}

@app.post("/predict")
def predict(item: TrafficData):
    db = SessionLocal()
    pr = Prediction(
        segment_id=item.segment_id,
        horizon_min=item.horizon_min,
        predicted_speed=item.predicted_speed,
        metadata_json={"model": item.model}
    )
    db.add(pr)
    db.commit()
    db.refresh(pr)
    db.close()
    return {"message": "Prediction stored successfully", "id": pr.id}

@app.get("/predictions")
def get_predictions():
    db = SessionLocal()
    data = db.query(Prediction).all()
    db.close()
    return data

# ------------------------------
# Run FastAPI inside Jupyter
def run_api():
    uvicorn.run(app, host="127.0.0.1", port=8000)

threading.Thread(target=run_api, daemon=True).start()
print("✅ Backend FastAPI running on http://127.0.0.1:8000")
# Out:
# Requirement already satisfied: fastapi in c:\users\91815\anaconda3\lib\site-packages (0.116.1)
# Requirement already satisfied: sqlalchemy in c:\users\91815\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: uvicorn in c:\users\91815\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: nest_asyncio in c:\users\91815\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: pydantic in c:\users\91815\anaconda3\lib\site-packages (2.5.3)
# Requirement already satisfied: streamlit in c:\users\91815\anaconda3\lib\site-packages (1.32.0)
# Requirement already satisfied: requests in c:\users\91815\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: pandas in c:\users\91815\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: starlette<0.48.0,>=0.40.0 in c:\users\91815\anaconda3\lib\site-packages (from fastapi) (0.47.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\91815\anaconda3\lib\site-packages (from fastapi) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\91815\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: click>=7.0 in c:\users\91815\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\91815\anaconda3\lib\site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\91815\anaconda3\lib\site-packages (from pydantic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.6 in c:\users\91815\anaconda3\lib\site-packages (from pydantic) (2.14.6)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (3.1.37)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\91815\anaconda3\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\91815\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\91815\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\91815\anaconda3\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\91815\anaconda3\lib\site-packages (from requests) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\91815\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91815\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\91815\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: jinja2 in c:\users\91815\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\91815\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in c:\users\91815\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\91815\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\91815\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: six>=1.5 in c:\users\91815\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\91815\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\91815\anaconda3\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\91815\anaconda3\lib\site-packages (from starlette<0.48.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\91815\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\91815\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\91815\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\91815\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\91815\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\91815\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\91815\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Requirement already satisfied: mdurl~=0.1 in c:\users\91815\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
# ✅ Backend FastAPI running on http://127.0.0.1:8000
# INFO:     Started server process [15488]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
